# %% [markdown]
# let us go with basic mining valors: jsw, lwb, kghm, cle
# NOTE: inflation and dividends are not taken into account

# %%
from src.DataDownloader import DataDownloader
from src.DataTransformer import DataTransformer
from const import *

# %%
download = DataDownloader(DataDownloadSource.STOOQ_PL)
data = download.get_single_stock("cla")
transform = DataTransformer()
df = transform.get_dataframe(data)
df = transform.clean_dataframe(df)
df
# Out:
#                open     high      low    close  volume
# date
# 2021-09-09  32.6930  32.6930  26.5057  29.1403    3399
# 2021-09-10  28.0226  28.6612  26.8409  27.9427     683
# 2021-09-13  26.8409  27.7831  26.5057  27.7831      36
# 2021-09-14  27.8629  27.8629  27.7831  27.7831      31
# 2021-09-15  27.7831  27.7831  26.3460  26.3460     871
# ...             ...      ...      ...      ...     ...
# 2025-11-18   7.7000   7.7000   7.7000   7.7000     216
# 2025-11-20   7.7500   7.7500   7.0500   7.0500    1130
# 2025-11-21   7.0000   7.0000   7.0000   7.0000       5
# 2025-11-24   7.3000   7.5500   7.0000   7.0000     791
# 2025-11-25   6.9500   7.2500   6.9500   7.2500     299
#
# [896 rows x 5 columns]
